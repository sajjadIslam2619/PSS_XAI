# %% [markdown]
# Title: The Distress Analysis Interview Corpus of human and computer interviews
#
# Link: https://dcapswoz.ict.usc.edu/
#
# Datasets link (access granted)
#
# https://dcapswoz.ict.usc.edu/wwwdaicwoz/  [Downloaded this dataset]
#
# https://dcapswoz.ict.usc.edu/wwwedaic/ [Not using extended dataset]

# %% [markdown]
# # Data description:
#
# The DAIC-WOZ Depression dataset is a subset of the Distress Analysis Interview Corpus containing Wizard-of-Oz clinical interviews, where participants interact with a virtual agent (Ellie) controlled by a human. Each session provides audio, video, and transcripts of the conversations, along with questionnaire responses such as the PHQ-8 for depression assessment.

# %% [markdown]
# # How to get conversation and it's label (depression)
#
# Conversation text can be obtained from the XXX_TRANSCRIPT.csv files in each participant’s folder, which include time-aligned utterances from both Ellie and the participant. Labels for depression are derived from the train_split_Depression_AVEC2017.csv and dev_split_Depression_AVEC2017.csv files in the util/ folder, where a PHQ-8 score of 10 or higher indicates depression, and scores below 10 indicate non-depression.

# %%
import os
import urllib.request
import zipfile

# Base URL for DAIC-WOZ data
BASE_URL = "https://dcapswoz.ict.usc.edu/wwwdaicwoz"

# Output directory where you want transcript CSVs
OUTPUT_DIR = r"D:\Sajjad-Workspace\Datasets\Dataset_6_Distress_Analysis_Interview\DAIC-WOZ"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Temporary directory for downloading zips
TEMP_DIR = os.path.join(OUTPUT_DIR, "tmp")
os.makedirs(TEMP_DIR, exist_ok=True)

# Loop through participant IDs
for pid in range(305, 493):  # 300 to 492
    zip_name = f"{pid}_P.zip"
    url = f"{BASE_URL}/{zip_name}"
    temp_zip_path = os.path.join(TEMP_DIR, zip_name)
    transcript_name = f"{pid}_TRANSCRIPT.csv"
    output_csv_path = os.path.join(OUTPUT_DIR, transcript_name)

    if os.path.exists(output_csv_path):
        print(f"Already have: {output_csv_path}")
        continue

    try:
        print(f"Downloading {zip_name} ...")
        urllib.request.urlretrieve(url, temp_zip_path)

        # Open zip and look for transcript
        with zipfile.ZipFile(temp_zip_path, "r") as zf:
            found = False
            for member in zf.namelist():
                if member.endswith("_TRANSCRIPT.csv"):
                    with zf.open(member) as src, open(output_csv_path, "wb") as dst:
                        dst.write(src.read())
                    print(f"✔ Extracted {transcript_name}")
                    found = True
                    break
            if not found:
                print(f"✘ Transcript not found in {zip_name}")

        # Remove temp zip after extraction
        os.remove(temp_zip_path)

    except Exception as e:
        print(f"⚠ Error with {zip_name}: {e}")
        if os.path.exists(temp_zip_path):
            os.remove(temp_zip_path)

print("Finished downloading and extracting transcripts.")
# Out:
# Downloading 305_P.zip ...
# ✔ Extracted 305_TRANSCRIPT.csv
# Downloading 306_P.zip ...
# ✔ Extracted 306_TRANSCRIPT.csv
# Downloading 307_P.zip ...
# ✔ Extracted 307_TRANSCRIPT.csv
# Downloading 308_P.zip ...
# ✔ Extracted 308_TRANSCRIPT.csv
# Downloading 309_P.zip ...
# ✔ Extracted 309_TRANSCRIPT.csv
# Downloading 310_P.zip ...
# ✔ Extracted 310_TRANSCRIPT.csv
# Downloading 311_P.zip ...
# ✔ Extracted 311_TRANSCRIPT.csv
# Downloading 312_P.zip ...
# ✔ Extracted 312_TRANSCRIPT.csv
# Downloading 313_P.zip ...
# ✔ Extracted 313_TRANSCRIPT.csv
# Downloading 314_P.zip ...
# ✔ Extracted 314_TRANSCRIPT.csv
# Downloading 315_P.zip ...
# ✔ Extracted 315_TRANSCRIPT.csv
# Downloading 316_P.zip ...
# ✔ Extracted 316_TRANSCRIPT.csv
# Downloading 317_P.zip ...
# ✔ Extracted 317_TRANSCRIPT.csv
# Downloading 318_P.zip ...
# ✔ Extracted 318_TRANSCRIPT.csv
# Downloading 319_P.zip ...
# ✔ Extracted 319_TRANSCRIPT.csv
# Downloading 320_P.zip ...
# ✔ Extracted 320_TRANSCRIPT.csv
# Downloading 321_P.zip ...
# ✔ Extracted 321_TRANSCRIPT.csv
# Downloading 322_P.zip ...
# ✔ Extracted 322_TRANSCRIPT.csv
# Downloading 323_P.zip ...
# ✔ Extracted 323_TRANSCRIPT.csv
# Downloading 324_P.zip ...
# ✔ Extracted 324_TRANSCRIPT.csv
# Downloading 325_P.zip ...
# ✔ Extracted 325_TRANSCRIPT.csv
# Downloading 326_P.zip ...
# ✔ Extracted 326_TRANSCRIPT.csv
# Downloading 327_P.zip ...
# ✔ Extracted 327_TRANSCRIPT.csv
# Downloading 328_P.zip ...
# ✔ Extracted 328_TRANSCRIPT.csv
# Downloading 329_P.zip ...
# ✔ Extracted 329_TRANSCRIPT.csv
# Downloading 330_P.zip ...
# ✔ Extracted 330_TRANSCRIPT.csv
# Downloading 331_P.zip ...
# ✔ Extracted 331_TRANSCRIPT.csv
# Downloading 332_P.zip ...
# ✔ Extracted 332_TRANSCRIPT.csv
# Downloading 333_P.zip ...
# ✔ Extracted 333_TRANSCRIPT.csv
# Downloading 334_P.zip ...
# ✔ Extracted 334_TRANSCRIPT.csv
# Downloading 335_P.zip ...
# ✔ Extracted 335_TRANSCRIPT.csv
# Downloading 336_P.zip ...
# ✔ Extracted 336_TRANSCRIPT.csv
# Downloading 337_P.zip ...
# ✔ Extracted 337_TRANSCRIPT.csv
# Downloading 338_P.zip ...
# ✔ Extracted 338_TRANSCRIPT.csv
# Downloading 339_P.zip ...
# ✔ Extracted 339_TRANSCRIPT.csv
# Downloading 340_P.zip ...
# ✔ Extracted 340_TRANSCRIPT.csv
# Downloading 341_P.zip ...
# ✔ Extracted 341_TRANSCRIPT.csv
# Downloading 342_P.zip ...
# ⚠ Error with 342_P.zip: HTTP Error 404: Not Found
# Downloading 343_P.zip ...
# ✔ Extracted 343_TRANSCRIPT.csv
# Downloading 344_P.zip ...
# ✔ Extracted 344_TRANSCRIPT.csv
# Downloading 345_P.zip ...
# ✔ Extracted 345_TRANSCRIPT.csv
# Downloading 346_P.zip ...
# ✔ Extracted 346_TRANSCRIPT.csv
# Downloading 347_P.zip ...
# ✔ Extracted 347_TRANSCRIPT.csv
# Downloading 348_P.zip ...
# ✔ Extracted 348_TRANSCRIPT.csv
# Downloading 349_P.zip ...
# ✔ Extracted 349_TRANSCRIPT.csv
# Downloading 350_P.zip ...
# ✔ Extracted 350_TRANSCRIPT.csv
# Downloading 351_P.zip ...
# ✔ Extracted 351_TRANSCRIPT.csv
# Downloading 352_P.zip ...
# ✔ Extracted 352_TRANSCRIPT.csv
# Downloading 353_P.zip ...
# ✔ Extracted 353_TRANSCRIPT.csv
# Downloading 354_P.zip ...
# ✔ Extracted 354_TRANSCRIPT.csv
# Downloading 355_P.zip ...
# ✔ Extracted 355_TRANSCRIPT.csv
# Downloading 356_P.zip ...
# ✔ Extracted 356_TRANSCRIPT.csv
# Downloading 357_P.zip ...
# ✔ Extracted 357_TRANSCRIPT.csv
# Downloading 358_P.zip ...
# ✔ Extracted 358_TRANSCRIPT.csv
# Downloading 359_P.zip ...
# ✔ Extracted 359_TRANSCRIPT.csv
# Downloading 360_P.zip ...
# ✔ Extracted 360_TRANSCRIPT.csv
# Downloading 361_P.zip ...
# ✔ Extracted 361_TRANSCRIPT.csv
# Downloading 362_P.zip ...
# ✔ Extracted 362_TRANSCRIPT.csv
# Downloading 363_P.zip ...
# ✔ Extracted 363_TRANSCRIPT.csv
# Downloading 364_P.zip ...
# ✔ Extracted 364_TRANSCRIPT.csv
# Downloading 365_P.zip ...
# ✔ Extracted 365_TRANSCRIPT.csv
# Downloading 366_P.zip ...
# ✔ Extracted 366_TRANSCRIPT.csv
# Downloading 367_P.zip ...
# ✔ Extracted 367_TRANSCRIPT.csv
# Downloading 368_P.zip ...
# ✔ Extracted 368_TRANSCRIPT.csv
# Downloading 369_P.zip ...
# ✔ Extracted 369_TRANSCRIPT.csv
# Downloading 370_P.zip ...
# ✔ Extracted 370_TRANSCRIPT.csv
# Downloading 371_P.zip ...
# ✔ Extracted 371_TRANSCRIPT.csv
# Downloading 372_P.zip ...
# ✔ Extracted 372_TRANSCRIPT.csv
# Downloading 373_P.zip ...
# ✔ Extracted 373_TRANSCRIPT.csv
# Downloading 374_P.zip ...
# ✔ Extracted 374_TRANSCRIPT.csv
# Downloading 375_P.zip ...
# ✔ Extracted 375_TRANSCRIPT.csv
# Downloading 376_P.zip ...
# ✔ Extracted 376_TRANSCRIPT.csv
# Downloading 377_P.zip ...
# ✔ Extracted 377_TRANSCRIPT.csv
# Downloading 378_P.zip ...
# ✔ Extracted 378_TRANSCRIPT.csv
# Downloading 379_P.zip ...
# ✔ Extracted 379_TRANSCRIPT.csv
# Downloading 380_P.zip ...
# ✔ Extracted 380_TRANSCRIPT.csv
# Downloading 381_P.zip ...
# ✔ Extracted 381_TRANSCRIPT.csv
# Downloading 382_P.zip ...
# ✔ Extracted 382_TRANSCRIPT.csv
# Downloading 383_P.zip ...
# ✔ Extracted 383_TRANSCRIPT.csv
# Downloading 384_P.zip ...
# ✔ Extracted 384_TRANSCRIPT.csv
# Downloading 385_P.zip ...
# ✔ Extracted 385_TRANSCRIPT.csv
# Downloading 386_P.zip ...
# ✔ Extracted 386_TRANSCRIPT.csv
# Downloading 387_P.zip ...
# ✔ Extracted 387_TRANSCRIPT.csv
# Downloading 388_P.zip ...
# ✔ Extracted 388_TRANSCRIPT.csv
# Downloading 389_P.zip ...
# ✔ Extracted 389_TRANSCRIPT.csv
# Downloading 390_P.zip ...
# ✔ Extracted 390_TRANSCRIPT.csv
# Downloading 391_P.zip ...
# ✔ Extracted 391_TRANSCRIPT.csv
# Downloading 392_P.zip ...
# ✔ Extracted 392_TRANSCRIPT.csv
# Downloading 393_P.zip ...
# ✔ Extracted 393_TRANSCRIPT.csv
# Downloading 394_P.zip ...
# ⚠ Error with 394_P.zip: HTTP Error 404: Not Found
# Downloading 395_P.zip ...
# ✔ Extracted 395_TRANSCRIPT.csv
# Downloading 396_P.zip ...
# ✔ Extracted 396_TRANSCRIPT.csv
# Downloading 397_P.zip ...
# ✔ Extracted 397_TRANSCRIPT.csv
# Downloading 398_P.zip ...
# ⚠ Error with 398_P.zip: HTTP Error 404: Not Found
# Downloading 399_P.zip ...
# ✔ Extracted 399_TRANSCRIPT.csv
# Downloading 400_P.zip ...
# ✔ Extracted 400_TRANSCRIPT.csv
# Downloading 401_P.zip ...
# ✔ Extracted 401_TRANSCRIPT.csv
# Downloading 402_P.zip ...
# ✔ Extracted 402_TRANSCRIPT.csv
# Downloading 403_P.zip ...
# ✔ Extracted 403_TRANSCRIPT.csv
# Downloading 404_P.zip ...
# ✔ Extracted 404_TRANSCRIPT.csv
# Downloading 405_P.zip ...
# ✔ Extracted 405_TRANSCRIPT.csv
# Downloading 406_P.zip ...
# ✔ Extracted 406_TRANSCRIPT.csv
# Downloading 407_P.zip ...
# ✔ Extracted 407_TRANSCRIPT.csv
# Downloading 408_P.zip ...
# ✔ Extracted 408_TRANSCRIPT.csv
# Downloading 409_P.zip ...
# ✔ Extracted 409_TRANSCRIPT.csv
# Downloading 410_P.zip ...
# ✔ Extracted 410_TRANSCRIPT.csv
# Downloading 411_P.zip ...
# ✔ Extracted 411_TRANSCRIPT.csv
# Downloading 412_P.zip ...
# ✔ Extracted 412_TRANSCRIPT.csv
# Downloading 413_P.zip ...
# ✔ Extracted 413_TRANSCRIPT.csv
# Downloading 414_P.zip ...
# ✔ Extracted 414_TRANSCRIPT.csv
# Downloading 415_P.zip ...
# ✔ Extracted 415_TRANSCRIPT.csv
# Downloading 416_P.zip ...
# ✔ Extracted 416_TRANSCRIPT.csv
# Downloading 417_P.zip ...
# ✔ Extracted 417_TRANSCRIPT.csv
# Downloading 418_P.zip ...
# ✔ Extracted 418_TRANSCRIPT.csv
# Downloading 419_P.zip ...
# ✔ Extracted 419_TRANSCRIPT.csv
# Downloading 420_P.zip ...
# ✔ Extracted 420_TRANSCRIPT.csv
# Downloading 421_P.zip ...
# ✔ Extracted 421_TRANSCRIPT.csv
# Downloading 422_P.zip ...
# ✔ Extracted 422_TRANSCRIPT.csv
# Downloading 423_P.zip ...
# ✔ Extracted 423_TRANSCRIPT.csv
# Downloading 424_P.zip ...
# ✔ Extracted 424_TRANSCRIPT.csv
# Downloading 425_P.zip ...
# ✔ Extracted 425_TRANSCRIPT.csv
# Downloading 426_P.zip ...
# ✔ Extracted 426_TRANSCRIPT.csv
# Downloading 427_P.zip ...
# ✔ Extracted 427_TRANSCRIPT.csv
# Downloading 428_P.zip ...
# ✔ Extracted 428_TRANSCRIPT.csv
# Downloading 429_P.zip ...
# ✔ Extracted 429_TRANSCRIPT.csv
# Downloading 430_P.zip ...
# ✔ Extracted 430_TRANSCRIPT.csv
# Downloading 431_P.zip ...
# ✔ Extracted 431_TRANSCRIPT.csv
# Downloading 432_P.zip ...
# ✔ Extracted 432_TRANSCRIPT.csv
# Downloading 433_P.zip ...
# ✔ Extracted 433_TRANSCRIPT.csv
# Downloading 434_P.zip ...
# ✔ Extracted 434_TRANSCRIPT.csv
# Downloading 435_P.zip ...
# ✔ Extracted 435_TRANSCRIPT.csv
# Downloading 436_P.zip ...
# ✔ Extracted 436_TRANSCRIPT.csv
# Downloading 437_P.zip ...
# ✔ Extracted 437_TRANSCRIPT.csv
# Downloading 438_P.zip ...
# ✔ Extracted 438_TRANSCRIPT.csv
# Downloading 439_P.zip ...
# ✔ Extracted 439_TRANSCRIPT.csv
# Downloading 440_P.zip ...
# ✔ Extracted 440_TRANSCRIPT.csv
# Downloading 441_P.zip ...
# ✔ Extracted 441_TRANSCRIPT.csv
# Downloading 442_P.zip ...
# ✔ Extracted 442_TRANSCRIPT.csv
# Downloading 443_P.zip ...
# ✔ Extracted 443_TRANSCRIPT.csv
# Downloading 444_P.zip ...
# ✔ Extracted 444_TRANSCRIPT.csv
# Downloading 445_P.zip ...
# ✔ Extracted 445_TRANSCRIPT.csv
# Downloading 446_P.zip ...
# ✔ Extracted 446_TRANSCRIPT.csv
# Downloading 447_P.zip ...
# ✔ Extracted 447_TRANSCRIPT.csv
# Downloading 448_P.zip ...
# ✔ Extracted 448_TRANSCRIPT.csv
# Downloading 449_P.zip ...
# ✔ Extracted 449_TRANSCRIPT.csv
# Downloading 450_P.zip ...
# ✔ Extracted 450_TRANSCRIPT.csv
# Downloading 451_P.zip ...
# ✔ Extracted 451_TRANSCRIPT.csv
# Downloading 452_P.zip ...
# ✔ Extracted 452_TRANSCRIPT.csv
# Downloading 453_P.zip ...
# ✔ Extracted 453_TRANSCRIPT.csv
# Downloading 454_P.zip ...
# ✔ Extracted 454_TRANSCRIPT.csv
# Downloading 455_P.zip ...
# ✔ Extracted 455_TRANSCRIPT.csv
# Downloading 456_P.zip ...
# ✔ Extracted 456_TRANSCRIPT.csv
# Downloading 457_P.zip ...
# ✔ Extracted 457_TRANSCRIPT.csv
# Downloading 458_P.zip ...
# ✔ Extracted 458_TRANSCRIPT.csv
# Downloading 459_P.zip ...
# ✔ Extracted 459_TRANSCRIPT.csv
# Downloading 460_P.zip ...
# ⚠ Error with 460_P.zip: HTTP Error 404: Not Found
# Downloading 461_P.zip ...
# ✔ Extracted 461_TRANSCRIPT.csv
# Downloading 462_P.zip ...
# ✔ Extracted 462_TRANSCRIPT.csv
# Downloading 463_P.zip ...
# ✔ Extracted 463_TRANSCRIPT.csv
# Downloading 464_P.zip ...
# ✔ Extracted 464_TRANSCRIPT.csv
# Downloading 465_P.zip ...
# ✔ Extracted 465_TRANSCRIPT.csv
# Downloading 466_P.zip ...
# ✔ Extracted 466_TRANSCRIPT.csv
# Downloading 467_P.zip ...
# ✔ Extracted 467_TRANSCRIPT.csv
# Downloading 468_P.zip ...
# ✔ Extracted 468_TRANSCRIPT.csv
# Downloading 469_P.zip ...
# ✔ Extracted 469_TRANSCRIPT.csv
# Downloading 470_P.zip ...
# ✔ Extracted 470_TRANSCRIPT.csv
# Downloading 471_P.zip ...
# ✔ Extracted 471_TRANSCRIPT.csv
# Downloading 472_P.zip ...
# ✔ Extracted 472_TRANSCRIPT.csv
# Downloading 473_P.zip ...
# ✔ Extracted 473_TRANSCRIPT.csv
# Downloading 474_P.zip ...
# ✔ Extracted 474_TRANSCRIPT.csv
# Downloading 475_P.zip ...
# ✔ Extracted 475_TRANSCRIPT.csv
# Downloading 476_P.zip ...
# ✔ Extracted 476_TRANSCRIPT.csv
# Downloading 477_P.zip ...
# ✔ Extracted 477_TRANSCRIPT.csv
# Downloading 478_P.zip ...
# ✔ Extracted 478_TRANSCRIPT.csv
# Downloading 479_P.zip ...
# ✔ Extracted 479_TRANSCRIPT.csv
# Downloading 480_P.zip ...
# ✔ Extracted 480_TRANSCRIPT.csv
# Downloading 481_P.zip ...
# ✔ Extracted 481_TRANSCRIPT.csv
# Downloading 482_P.zip ...
# ✔ Extracted 482_TRANSCRIPT.csv
# Downloading 483_P.zip ...
# ✔ Extracted 483_TRANSCRIPT.csv
# Downloading 484_P.zip ...
# ✔ Extracted 484_TRANSCRIPT.csv
# Downloading 485_P.zip ...
# ✔ Extracted 485_TRANSCRIPT.csv
# Downloading 486_P.zip ...
# ✔ Extracted 486_TRANSCRIPT.csv
# Downloading 487_P.zip ...
# ✔ Extracted 487_TRANSCRIPT.csv
# Downloading 488_P.zip ...
# ✔ Extracted 488_TRANSCRIPT.csv
# Downloading 489_P.zip ...
# ✔ Extracted 489_TRANSCRIPT.csv
# Downloading 490_P.zip ...
# ✔ Extracted 490_TRANSCRIPT.csv
# Downloading 491_P.zip ...
# ✔ Extracted 491_TRANSCRIPT.csv
# Downloading 492_P.zip ...
# ✔ Extracted 492_TRANSCRIPT.csv
# Finished downloading and extracting transcripts.
